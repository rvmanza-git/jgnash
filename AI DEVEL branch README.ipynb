# %%
AI DEVEL Branch notes

This branch hosts development made with GitHub AI. It is a means for a user to get essential new features while the main branch is not under active development.

To run: ./gradlew :jgnash-fx:run --args="--bypassBootloader"
